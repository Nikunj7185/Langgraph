# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langgraph.graph import StateGraph,END
from typing import TypedDict, Annotated
import operator
from langchain_core.messages import AnyMessage, AIMessage, HumanMessage, ToolMessage, SystemMessage
from langchain_groq import ChatGroq
from langchain_community.tools.tavily_search import TavilySearchResults
from langgraph.checkpoint.sqlite import SqliteSaver

# Manually enter context manager
memory_context = SqliteSaver.from_conn_string(":memory:")
memory = memory_context.__enter__()

# %%
from uuid import uuid4

def reduce_message(left:list[AnyMessage],right:list[AnyMessage]):
    for message in right:
        if not message.id:
            message.id=str(uuid4())
    
    merged=left.copy()
    for message in right:
        for i,existing in enumerate(merged):
            if existing.id==message.id:
                merged[i]=message
                break
        else:
            merged.append(message)
    return merged

class AgentState(TypedDict):
    messages: Annotated[list[AnyMessage],reduce_message]

# %%
tool=TavilySearchResults(max_results=2)

class Agent:
    def __init__(self,model,tools,checkpointer,system=""):
        self.system=system
        graph=StateGraph(AgentState)
        graph.add_node("llm",self.call_groq)
        graph.add_node("action",self.take_action)
        graph.add_conditional_edges(
            "llm",
            self.action_exists,
            {True:"action",False:END}
        )
        graph.add_edge("action","llm")
        graph.set_entry_point("llm")
        self.graph=graph.compile(checkpointer=checkpointer,interrupt_before=['action'])
        self.tools={t.name:t for t in tools}
        self.model=model.bind_tools(tools)
        
    def action_exists(self,state:AgentState):
        result=state['messages'][-1]
        return len(result.tool_calls)>0
        
        
    def call_groq(self,state:AgentState):
        messages=state["messages"]
        if self.system:
            messages=[SystemMessage(content=self.system)] + messages
        message=self.model.invoke(messages)
        return {'messages':[message]}
    
    def take_action(self,state:AgentState):
        tool_calls=state['messages'][-1].tool_calls
        results=[]
        for t in tool_calls:
            print(f'Calling: {t}')
            result=self.tools[t['name']].invoke(t['args'])
            results.append(ToolMessage(tool_call_id=t["id"],name=t["name"],content=str(result)))
        print("Back to the Model !!")
        return {"messages":results}

# %%
prompt = """You are a smart research assistant. Use the search engine to help answer user questions.
You are allowed to make multiple calls (either together or in sequence).
Only look up information when you are sure of what you want.
If you need to look up some information before asking a follow-up question, do so.
Be efficient and clear in your responses."""

tools=[tool]
abot=Agent(ChatGroq(model='llama3-8b-8192'),tools=tools,checkpointer=memory,system=prompt)

# %%
messages=[HumanMessage("What is the weather in varanasi ?")]
thread={"configurable":{"thread_id":"1"}}
for event in abot.graph.stream({"messages":messages},thread):
    for v in event.values():
        print(v)
# Out:
# {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_tgfx', 'function': {'arguments': '{"query":"weather in Varanasi"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 74, 'prompt_tokens': 2063, 'total_tokens': 2137, 'completion_time': 0.061666667, 'prompt_time': 0.259154638, 'queue_time': -0.315787895, 'total_time': 0.320821305}, 'model_name': 'llama3-8b-8192', 'system_fingerprint': 'fp_dadc9d6142', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-c2c0568a-f6fc-42b1-82bd-83535a1d9113-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Varanasi'}, 'id': 'call_tgfx', 'type': 'tool_call'}], usage_metadata={'input_tokens': 2063, 'output_tokens': 74, 'total_tokens': 2137})]}
# ()

# %%
abot.graph.get_state(thread)
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='What is the weather in varanasi ?', additional_kwargs={}, response_metadata={}, id='f3337f2b-3e60-465a-b9c6-2eb2d05a7585'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_tgfx', 'function': {'arguments': '{"query":"weather in Varanasi"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 74, 'prompt_tokens': 2063, 'total_tokens': 2137, 'completion_time': 0.061666667, 'prompt_time': 0.259154638, 'queue_time': -0.315787895, 'total_time': 0.320821305}, 'model_name': 'llama3-8b-8192', 'system_fingerprint': 'fp_dadc9d6142', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-c2c0568a-f6fc-42b1-82bd-83535a1d9113-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Varanasi'}, 'id': 'call_tgfx', 'type': 'tool_call'}], usage_metadata={'input_tokens': 2063, 'output_tokens': 74, 'total_tokens': 2137})]}, next=('action',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f01e791-74a0-6663-8001-1fa1b747f21d'}}, metadata={'source': 'loop', 'writes': {'llm': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_tgfx', 'function': {'arguments': '{"query":"weather in Varanasi"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 74, 'prompt_tokens': 2063, 'total_tokens': 2137, 'completion_time': 0.061666667, 'prompt_time': 0.259154638, 'queue_time': -0.315787895, 'total_time': 0.320821305}, 'model_name': 'llama3-8b-8192', 'system_fingerprint': 'fp_dadc9d6142', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-c2c0568a-f6fc-42b1-82bd-83535a1d9113-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Varanasi'}, 'id': 'call_tgfx', 'type': 'tool_call'}], usage_metadata={'input_tokens': 2063, 'output_tokens': 74, 'total_tokens': 2137})]}}, 'step': 1, 'parents': {}, 'thread_id': '1'}, created_at='2025-04-21T06:23:07.908873+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f01e791-673a-6d47-8000-a6c197c92ac8'}}, tasks=(PregelTask(id='941d026f-4244-9da6-c62a-a0b06923a956', name='action', path=('__pregel_pull', 'action'), error=None, interrupts=(), state=None, result=None),))

# %%
abot.graph.get_state(thread).next
# Out:
# ('action',)

# %%
for event in abot.graph.stream(None,thread):
    for v in event.values():
        print(v)
# Out:
# Calling: {'name': 'tavily_search_results_json', 'args': {'query': 'weather in Varanasi'}, 'id': 'call_tgfx', 'type': 'tool_call'}
# Back to the Model !!
# {'messages': [ToolMessage(content="[{'title': 'Weather in Varanasi in April 2025 (State of Uttar Pradesh)', 'url': 'https://world-weather.info/forecast/india/varanasi/april-2025/', 'content': 'Weather in Varanasi in April 2025. Varanasi Weather Forecast for April 2025 ... Monday, 21 April. +81°. Day. +100°. Clear sky. Tuesday, 22 April. +82°. Day. +99', 'score': 0.95407325}, {'title': 'Varanasi weather in April 2025 ⋆ Varanasi temperature in April ...', 'url': 'https://www.meteoprog.com/weather/Varanasi/month/april/', 'content': 'Varanasi (India) weather in April 2025 ☀ Accurate weather forecast for Varanasi in ... 21 Apr. +38°+26°. 22 Apr. +39°+25°. 23 Apr. +39°+26°. 24 Apr. +40°+25°. 25', 'score': 0.93161833}]", name='tavily_search_results_json', id='19bf356e-386a-4f1e-b76b-29089e932b85', tool_call_id='call_tgfx')]}
# {'messages': [AIMessage(content='The weather in Varanasi in April 2025 is expected to be pleasant with clear skies and temperatures ranging from +38°C to +40°C (100°F to 104°F).', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 39, 'prompt_tokens': 1333, 'total_tokens': 1372, 'completion_time': 0.0325, 'prompt_time': 0.166152419, 'queue_time': 0.239158945, 'total_time': 0.198652419}, 'model_name': 'llama3-8b-8192', 'system_fingerprint': 'fp_a97cfe35ae', 'finish_reason': 'stop', 'logprobs': None}, id='run-eade7726-01f7-4086-85e9-e4301f147d7f-0', usage_metadata={'input_tokens': 1333, 'output_tokens': 39, 'total_tokens': 1372})]}

# %%
abot.graph.get_state(thread)
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='What is the weather in varanasi ?', additional_kwargs={}, response_metadata={}, id='f3337f2b-3e60-465a-b9c6-2eb2d05a7585'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_tgfx', 'function': {'arguments': '{"query":"weather in Varanasi"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 74, 'prompt_tokens': 2063, 'total_tokens': 2137, 'completion_time': 0.061666667, 'prompt_time': 0.259154638, 'queue_time': -0.315787895, 'total_time': 0.320821305}, 'model_name': 'llama3-8b-8192', 'system_fingerprint': 'fp_dadc9d6142', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-c2c0568a-f6fc-42b1-82bd-83535a1d9113-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Varanasi'}, 'id': 'call_tgfx', 'type': 'tool_call'}], usage_metadata={'input_tokens': 2063, 'output_tokens': 74, 'total_tokens': 2137}), ToolMessage(content="[{'title': 'Weather in Varanasi in April 2025 (State of Uttar Pradesh)', 'url': 'https://world-weather.info/forecast/india/varanasi/april-2025/', 'content': 'Weather in Varanasi in April 2025. Varanasi Weather Forecast for April 2025 ... Monday, 21 April. +81°. Day. +100°. Clear sky. Tuesday, 22 April. +82°. Day. +99', 'score': 0.95407325}, {'title': 'Varanasi weather in April 2025 ⋆ Varanasi temperature in April ...', 'url': 'https://www.meteoprog.com/weather/Varanasi/month/april/', 'content': 'Varanasi (India) weather in April 2025 ☀ Accurate weather forecast for Varanasi in ... 21 Apr. +38°+26°. 22 Apr. +39°+25°. 23 Apr. +39°+26°. 24 Apr. +40°+25°. 25', 'score': 0.93161833}]", name='tavily_search_results_json', id='19bf356e-386a-4f1e-b76b-29089e932b85', tool_call_id='call_tgfx'), AIMessage(content='The weather in Varanasi in April 2025 is expected to be pleasant with clear skies and temperatures ranging from +38°C to +40°C (100°F to 104°F).', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 39, 'prompt_tokens': 1333, 'total_tokens': 1372, 'completion_time': 0.0325, 'prompt_time': 0.166152419, 'queue_time': 0.239158945, 'total_time': 0.198652419}, 'model_name': 'llama3-8b-8192', 'system_fingerprint': 'fp_a97cfe35ae', 'finish_reason': 'stop', 'logprobs': None}, id='run-eade7726-01f7-4086-85e9-e4301f147d7f-0', usage_metadata={'input_tokens': 1333, 'output_tokens': 39, 'total_tokens': 1372})]}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f01e791-aeaa-619e-8003-f36fb28b6e58'}}, metadata={'source': 'loop', 'writes': {'llm': {'messages': [AIMessage(content='The weather in Varanasi in April 2025 is expected to be pleasant with clear skies and temperatures ranging from +38°C to +40°C (100°F to 104°F).', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 39, 'prompt_tokens': 1333, 'total_tokens': 1372, 'completion_time': 0.0325, 'prompt_time': 0.166152419, 'queue_time': 0.239158945, 'total_time': 0.198652419}, 'model_name': 'llama3-8b-8192', 'system_fingerprint': 'fp_a97cfe35ae', 'finish_reason': 'stop', 'logprobs': None}, id='run-eade7726-01f7-4086-85e9-e4301f147d7f-0', usage_metadata={'input_tokens': 1333, 'output_tokens': 39, 'total_tokens': 1372})]}}, 'step': 3, 'parents': {}, 'thread_id': '1'}, created_at='2025-04-21T06:23:13.994588+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f01e791-a5f0-6744-8002-67a80f08c8bc'}}, tasks=())

# %%
abot.graph.get_state(thread).next
# Out:
# ()

# %%
messages=[HumanMessage("What is the weather in Varanasi ?")]
thread={"configurable":{"thread_id":"2"}}
for event in abot.graph.stream({"messages":messages},thread):
    for v in event.values():
        print(v)
# Out:
# {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_9h7b', 'function': {'arguments': '{"query":"weather in Varanasi"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 81, 'prompt_tokens': 1021, 'total_tokens': 1102, 'completion_time': 0.0675, 'prompt_time': 0.141173133, 'queue_time': 0.23376384499999997, 'total_time': 0.208673133}, 'model_name': 'llama3-8b-8192', 'system_fingerprint': 'fp_a97cfe35ae', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-ee522ff3-7e73-4744-ba7e-904f649f981f-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Varanasi'}, 'id': 'call_9h7b', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1021, 'output_tokens': 81, 'total_tokens': 1102})]}
# ()

# %%
abot.graph.get_state(thread)
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='What is the weather in Varanasi ?', additional_kwargs={}, response_metadata={}, id='9eeae9f1-1d7d-4104-9356-6147a2e448c0'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_9h7b', 'function': {'arguments': '{"query":"weather in Varanasi"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 81, 'prompt_tokens': 1021, 'total_tokens': 1102, 'completion_time': 0.0675, 'prompt_time': 0.141173133, 'queue_time': 0.23376384499999997, 'total_time': 0.208673133}, 'model_name': 'llama3-8b-8192', 'system_fingerprint': 'fp_a97cfe35ae', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-ee522ff3-7e73-4744-ba7e-904f649f981f-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Varanasi'}, 'id': 'call_9h7b', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1021, 'output_tokens': 81, 'total_tokens': 1102})]}, next=('action',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f01e791-b609-6b14-8001-5867b9d85469'}}, metadata={'source': 'loop', 'writes': {'llm': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_9h7b', 'function': {'arguments': '{"query":"weather in Varanasi"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 81, 'prompt_tokens': 1021, 'total_tokens': 1102, 'completion_time': 0.0675, 'prompt_time': 0.141173133, 'queue_time': 0.23376384499999997, 'total_time': 0.208673133}, 'model_name': 'llama3-8b-8192', 'system_fingerprint': 'fp_a97cfe35ae', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-ee522ff3-7e73-4744-ba7e-904f649f981f-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Varanasi'}, 'id': 'call_9h7b', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1021, 'output_tokens': 81, 'total_tokens': 1102})]}}, 'step': 1, 'parents': {}, 'thread_id': '2'}, created_at='2025-04-21T06:23:14.767746+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f01e791-af41-60ff-8000-386c80d3fc7b'}}, tasks=(PregelTask(id='2821705d-4a16-f2db-636a-b8d3907ef0bd', name='action', path=('__pregel_pull', 'action'), error=None, interrupts=(), state=None, result=None),))

# %%
abot.graph.get_state(thread).next
# Out:
# ('action',)

# %%
current_values=abot.graph.get_state(thread)
current_values.values['messages'][-1]
# Out:
# AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_9h7b', 'function': {'arguments': '{"query":"weather in Varanasi"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 81, 'prompt_tokens': 1021, 'total_tokens': 1102, 'completion_time': 0.0675, 'prompt_time': 0.141173133, 'queue_time': 0.23376384499999997, 'total_time': 0.208673133}, 'model_name': 'llama3-8b-8192', 'system_fingerprint': 'fp_a97cfe35ae', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-ee522ff3-7e73-4744-ba7e-904f649f981f-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Varanasi'}, 'id': 'call_9h7b', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1021, 'output_tokens': 81, 'total_tokens': 1102})

# %%
current_values.values['messages'][-1].tool_calls
# Out:
# [{'name': 'tavily_search_results_json',
#   'args': {'query': 'weather in Varanasi'},
#   'id': 'call_9h7b',
#   'type': 'tool_call'}]

# %%
current_values.values['messages'][-1].tool_calls[0]['args']['query']='weather in Noida'
current_values
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='What is the weather in Varanasi ?', additional_kwargs={}, response_metadata={}, id='9eeae9f1-1d7d-4104-9356-6147a2e448c0'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_9h7b', 'function': {'arguments': '{"query":"weather in Varanasi"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 81, 'prompt_tokens': 1021, 'total_tokens': 1102, 'completion_time': 0.0675, 'prompt_time': 0.141173133, 'queue_time': 0.23376384499999997, 'total_time': 0.208673133}, 'model_name': 'llama3-8b-8192', 'system_fingerprint': 'fp_a97cfe35ae', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-ee522ff3-7e73-4744-ba7e-904f649f981f-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Noida'}, 'id': 'call_9h7b', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1021, 'output_tokens': 81, 'total_tokens': 1102})]}, next=('action',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f01e791-b609-6b14-8001-5867b9d85469'}}, metadata={'source': 'loop', 'writes': {'llm': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_9h7b', 'function': {'arguments': '{"query":"weather in Varanasi"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 81, 'prompt_tokens': 1021, 'total_tokens': 1102, 'completion_time': 0.0675, 'prompt_time': 0.141173133, 'queue_time': 0.23376384499999997, 'total_time': 0.208673133}, 'model_name': 'llama3-8b-8192', 'system_fingerprint': 'fp_a97cfe35ae', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-ee522ff3-7e73-4744-ba7e-904f649f981f-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Varanasi'}, 'id': 'call_9h7b', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1021, 'output_tokens': 81, 'total_tokens': 1102})]}}, 'step': 1, 'parents': {}, 'thread_id': '2'}, created_at='2025-04-21T06:23:14.767746+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f01e791-af41-60ff-8000-386c80d3fc7b'}}, tasks=(PregelTask(id='2821705d-4a16-f2db-636a-b8d3907ef0bd', name='action', path=('__pregel_pull', 'action'), error=None, interrupts=(), state=None, result=None),))

# %%
abot.graph.update_state(thread,current_values.values)
# Out:
# {'configurable': {'thread_id': '2',
#   'checkpoint_ns': '',
#   'checkpoint_id': '1f01e791-b6e2-68d2-8002-42ad104b5c73'}}

# %%
abot.graph.get_state(thread)
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='What is the weather in Varanasi ?', additional_kwargs={}, response_metadata={}, id='9eeae9f1-1d7d-4104-9356-6147a2e448c0'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_9h7b', 'function': {'arguments': '{"query":"weather in Varanasi"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 81, 'prompt_tokens': 1021, 'total_tokens': 1102, 'completion_time': 0.0675, 'prompt_time': 0.141173133, 'queue_time': 0.23376384499999997, 'total_time': 0.208673133}, 'model_name': 'llama3-8b-8192', 'system_fingerprint': 'fp_a97cfe35ae', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-ee522ff3-7e73-4744-ba7e-904f649f981f-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Noida'}, 'id': 'call_9h7b', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1021, 'output_tokens': 81, 'total_tokens': 1102})]}, next=('action',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f01e791-b6e2-68d2-8002-42ad104b5c73'}}, metadata={'source': 'update', 'writes': {'llm': {'messages': [HumanMessage(content='What is the weather in Varanasi ?', additional_kwargs={}, response_metadata={}, id='9eeae9f1-1d7d-4104-9356-6147a2e448c0'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_9h7b', 'function': {'arguments': '{"query":"weather in Varanasi"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 81, 'prompt_tokens': 1021, 'total_tokens': 1102, 'completion_time': 0.0675, 'prompt_time': 0.141173133, 'queue_time': 0.23376384499999997, 'total_time': 0.208673133}, 'model_name': 'llama3-8b-8192', 'system_fingerprint': 'fp_a97cfe35ae', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-ee522ff3-7e73-4744-ba7e-904f649f981f-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Noida'}, 'id': 'call_9h7b', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1021, 'output_tokens': 81, 'total_tokens': 1102})]}}, 'step': 2, 'parents': {}, 'thread_id': '2'}, created_at='2025-04-21T06:23:14.856571+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f01e791-b609-6b14-8001-5867b9d85469'}}, tasks=(PregelTask(id='f20f86f6-2490-410f-5e12-24b52b4a08d7', name='action', path=('__pregel_pull', 'action'), error=None, interrupts=(), state=None, result=None),))

# %%
for event in abot.graph.stream(None,thread):
    for v in event.values():
        print(v)
# Out:
# Calling: {'name': 'tavily_search_results_json', 'args': {'query': 'weather in Noida'}, 'id': 'call_9h7b', 'type': 'tool_call'}
# Back to the Model !!
# {'messages': [ToolMessage(content='[{\'title\': \'Weather in Noida\', \'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Noida\', \'region\': \'Uttar Pradesh\', \'country\': \'India\', \'lat\': 28.57, \'lon\': 77.32, \'tz_id\': \'Asia/Kolkata\', \'localtime_epoch\': 1745216597, \'localtime\': \'2025-04-21 11:53\'}, \'current\': {\'last_updated_epoch\': 1745216100, \'last_updated\': \'2025-04-21 11:45\', \'temp_c\': 36.3, \'temp_f\': 97.3, \'is_day\': 1, \'condition\': {\'text\': \'Mist\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/day/143.png\', \'code\': 1030}, \'wind_mph\': 6.5, \'wind_kph\': 10.4, \'wind_degree\': 215, \'wind_dir\': \'SW\', \'pressure_mb\': 1009.0, \'pressure_in\': 29.8, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 15, \'cloud\': 0, \'feelslike_c\': 34.8, \'feelslike_f\': 94.6, \'windchill_c\': 39.0, \'windchill_f\': 102.3, \'heatindex_c\': 38.5, \'heatindex_f\': 101.3, \'dewpoint_c\': -6.3, \'dewpoint_f\': 20.7, \'vis_km\': 4.5, \'vis_miles\': 2.0, \'uv\': 9.3, \'gust_mph\': 7.5, \'gust_kph\': 12.0}}", \'score\': 0.9688681}, {\'title\': \'Noida Weather Forecast 21 Apr 2025 - Times of India\', \'url\': \'https://timesofindia.indiatimes.com/weather/noida-weather-forecast-today/201301\', \'content\': "Today\'s Weather in Noida: In Noida today, the weather is expected to be Haze with a maximum temperature of 38°C and a minimum of 27°C. Sunrise in Noida is", \'score\': 0.9456058}]', name='tavily_search_results_json', id='7dbc12b2-ec4c-4a29-a7bb-b431a87cfad1', tool_call_id='call_9h7b')]}
# {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_vmde', 'function': {'arguments': '{"query":"weather in Varanasi"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 78, 'prompt_tokens': 1626, 'total_tokens': 1704, 'completion_time': 0.065, 'prompt_time': 0.204505117, 'queue_time': 0.02333338900000001, 'total_time': 0.269505117}, 'model_name': 'llama3-8b-8192', 'system_fingerprint': 'fp_a97cfe35ae', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-5cf02b02-0173-466f-9938-aa7896b9037c-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Varanasi'}, 'id': 'call_vmde', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1626, 'output_tokens': 78, 'total_tokens': 1704})]}
# ()

# %%
for event in abot.graph.stream(None,thread):
    for v in event.values():
        print(v)
# Out:
# Calling: {'name': 'tavily_search_results_json', 'args': {'query': 'weather in Varanasi'}, 'id': 'call_vmde', 'type': 'tool_call'}
# Back to the Model !!
# {'messages': [ToolMessage(content="[{'title': 'Weather in Varanasi in April 2025 (State of Uttar Pradesh)', 'url': 'https://world-weather.info/forecast/india/varanasi/april-2025/', 'content': 'Weather in Varanasi in April 2025. Varanasi Weather Forecast for April 2025 ... Monday, 21 April. +81°. Day. +100°. Clear sky. Tuesday, 22 April. +82°. Day. +99', 'score': 0.95407325}, {'title': 'Varanasi weather in April 2025 ⋆ Varanasi temperature in April ...', 'url': 'https://www.meteoprog.com/weather/Varanasi/month/april/', 'content': 'Varanasi (India) weather in April 2025 ☀ Accurate weather forecast for Varanasi in ... 21 Apr. +38°+26°. 22 Apr. +39°+25°. 23 Apr. +39°+26°. 24 Apr. +40°+25°. 25', 'score': 0.93161833}]", name='tavily_search_results_json', id='6b1573a1-fe4f-483d-a173-205a4c2fafde', tool_call_id='call_vmde')]}
# {'messages': [AIMessage(content='The weather in Varanasi is expected to be warm and sunny in April 2025, with temperatures ranging from 38°C to 40°C during the day and 25°C to 26°C at night.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 45, 'prompt_tokens': 1938, 'total_tokens': 1983, 'completion_time': 0.0375, 'prompt_time': 0.27767245, 'queue_time': 0.11456181399999998, 'total_time': 0.31517245}, 'model_name': 'llama3-8b-8192', 'system_fingerprint': 'fp_179b0f92c9', 'finish_reason': 'stop', 'logprobs': None}, id='run-a21a6fb1-e347-43dd-b9f1-1c16dba3176f-0', usage_metadata={'input_tokens': 1938, 'output_tokens': 45, 'total_tokens': 1983})]}

# %%
states=[]
for state in abot.graph.get_state_history(thread):
    print(state)
    print("------")
    states.append(state)
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='What is the weather in Varanasi ?', additional_kwargs={}, response_metadata={}, id='9eeae9f1-1d7d-4104-9356-6147a2e448c0'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_9h7b', 'function': {'arguments': '{"query":"weather in Varanasi"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 81, 'prompt_tokens': 1021, 'total_tokens': 1102, 'completion_time': 0.0675, 'prompt_time': 0.141173133, 'queue_time': 0.23376384499999997, 'total_time': 0.208673133}, 'model_name': 'llama3-8b-8192', 'system_fingerprint': 'fp_a97cfe35ae', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-ee522ff3-7e73-4744-ba7e-904f649f981f-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Noida'}, 'id': 'call_9h7b', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1021, 'output_tokens': 81, 'total_tokens': 1102}), ToolMessage(content='[{\'title\': \'Weather in Noida\', \'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Noida\', \'region\': \'Uttar Pradesh\', \'country\': \'India\', \'lat\': 28.57, \'lon\': 77.32, \'tz_id\': \'Asia/Kolkata\', \'localtime_epoch\': 1745216597, \'localtime\': \'2025-04-21 11:53\'}, \'current\': {\'last_updated_epoch\': 1745216100, \'last_updated\': \'2025-04-21 11:45\', \'temp_c\': 36.3, \'temp_f\': 97.3, \'is_day\': 1, \'condition\': {\'text\': \'Mist\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/day/143.png\', \'code\': 1030}, \'wind_mph\': 6.5, \'wind_kph\': 10.4, \'wind_degree\': 215, \'wind_dir\': \'SW\', \'pressure_mb\': 1009.0, \'pressure_in\': 29.8, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 15, \'cloud\': 0, \'feelslike_c\': 34.8, \'feelslike_f\': 94.6, \'windchill_c\': 39.0, \'windchill_f\': 102.3, \'heatindex_c\': 38.5, \'heatindex_f\': 101.3, \'dewpoint_c\': -6.3, \'dewpoint_f\': 20.7, \'vis_km\': 4.5, \'vis_miles\': 2.0, \'uv\': 9.3, \'gust_mph\': 7.5, \'gust_kph\': 12.0}}", \'score\': 0.9688681}, {\'title\': \'Noida Weather Forecast 21 Apr 2025 - Times of India\', \'url\': \'https://timesofindia.indiatimes.com/weather/noida-weather-forecast-today/201301\', \'content\': "Today\'s Weather in Noida: In Noida today, the weather is expected to be Haze with a maximum temperature of 38°C and a minimum of 27°C. Sunrise in Noida is", \'score\': 0.9456058}]', name='tavily_search_results_json', id='7dbc12b2-ec4c-4a29-a7bb-b431a87cfad1', tool_call_id='call_9h7b'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_vmde', 'function': {'arguments': '{"query":"weather in Varanasi"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 78, 'prompt_tokens': 1626, 'total_tokens': 1704, 'completion_time': 0.065, 'prompt_time': 0.204505117, 'queue_time': 0.02333338900000001, 'total_time': 0.269505117}, 'model_name': 'llama3-8b-8192', 'system_fingerprint': 'fp_a97cfe35ae', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-5cf02b02-0173-466f-9938-aa7896b9037c-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Varanasi'}, 'id': 'call_vmde', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1626, 'output_tokens': 78, 'total_tokens': 1704}), ToolMessage(content="[{'title': 'Weather in Varanasi in April 2025 (State of Uttar Pradesh)', 'url': 'https://world-weather.info/forecast/india/varanasi/april-2025/', 'content': 'Weather in Varanasi in April 2025. Varanasi Weather Forecast for April 2025 ... Monday, 21 April. +81°. Day. +100°. Clear sky. Tuesday, 22 April. +82°. Day. +99', 'score': 0.95407325}, {'title': 'Varanasi weather in April 2025 ⋆ Varanasi temperature in April ...', 'url': 'https://www.meteoprog.com/weather/Varanasi/month/april/', 'content': 'Varanasi (India) weather in April 2025 ☀ Accurate weather forecast for Varanasi in ... 21 Apr. +38°+26°. 22 Apr. +39°+25°. ...
# ------
# StateSnapshot(values={'messages': [HumanMessage(content='What is the weather in Varanasi ?', additional_kwargs={}, response_metadata={}, id='9eeae9f1-1d7d-4104-9356-6147a2e448c0'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_9h7b', 'function': {'arguments': '{"query":"weather in Varanasi"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 81, 'prompt_tokens': 1021, 'total_tokens': 1102, 'completion_time': 0.0675, 'prompt_time': 0.141173133, 'queue_time': 0.23376384499999997, 'total_time': 0.208673133}, 'model_name': 'llama3-8b-8192', 'system_fingerprint': 'fp_a97cfe35ae', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-ee522ff3-7e73-4744-ba7e-904f649f981f-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Noida'}, 'id': 'call_9h7b', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1021, 'output_tokens': 81, 'total_tokens': 1102}), ToolMessage(content='[{\'title\': \'Weather in Noida\', \'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Noida\', \'region\': \'Uttar Pradesh\', \'country\': \'India\', \'lat\': 28.57, \'lon\': 77.32, \'tz_id\': \'Asia/Kolkata\', \'localtime_epoch\': 1745216597, \'localtime\': \'2025-04-21 11:53\'}, \'current\': {\'last_updated_epoch\': 1745216100, \'last_updated\': \'2025-04-21 11:45\', \'temp_c\': 36.3, \'temp_f\': 97.3, \'is_day\': 1, \'condition\': {\'text\': \'Mist\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/day/143.png\', \'code\': 1030}, \'wind_mph\': 6.5, \'wind_kph\': 10.4, \'wind_degree\': 215, \'wind_dir\': \'SW\', \'pressure_mb\': 1009.0, \'pressure_in\': 29.8, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 15, \'cloud\': 0, \'feelslike_c\': 34.8, \'feelslike_f\': 94.6, \'windchill_c\': 39.0, \'windchill_f\': 102.3, \'heatindex_c\': 38.5, \'heatindex_f\': 101.3, \'dewpoint_c\': -6.3, \'dewpoint_f\': 20.7, \'vis_km\': 4.5, \'vis_miles\': 2.0, \'uv\': 9.3, \'gust_mph\': 7.5, \'gust_kph\': 12.0}}", \'score\': 0.9688681}, {\'title\': \'Noida Weather Forecast 21 Apr 2025 - Times of India\', \'url\': \'https://timesofindia.indiatimes.com/weather/noida-weather-forecast-today/201301\', \'content\': "Today\'s Weather in Noida: In Noida today, the weather is expected to be Haze with a maximum temperature of 38°C and a minimum of 27°C. Sunrise in Noida is", \'score\': 0.9456058}]', name='tavily_search_results_json', id='7dbc12b2-ec4c-4a29-a7bb-b431a87cfad1', tool_call_id='call_9h7b'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_vmde', 'function': {'arguments': '{"query":"weather in Varanasi"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 78, 'prompt_tokens': 1626, 'total_tokens': 1704, 'completion_time': 0.065, 'prompt_time': 0.204505117, 'queue_time': 0.02333338900000001, 'total_time': 0.269505117}, 'model_name': 'llama3-8b-8192', 'system_fingerprint': 'fp_a97cfe35ae', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-5cf02b02-0173-466f-9938-aa7896b9037c-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Varanasi'}, 'id': 'call_vmde', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1626, 'output_tokens': 78, 'total_tokens': 1704}), ToolMessage(content="[{'title': 'Weather in Varanasi in April 2025 (State of Uttar Pradesh)', 'url': 'https://world-weather.info/forecast/india/varanasi/april-2025/', 'content': 'Weather in Varanasi in April 2025. Varanasi Weather Forecast for April 2025 ... Monday, 21 April. +81°. Day. +100°. Clear sky. Tuesday, 22 April. +82°. Day. +99', 'score': 0.95407325}, {'title': 'Varanasi weather in April 2025 ⋆ Varanasi temperature in April ...', 'url': 'https://www.meteoprog.com/weather/Varanasi/month/april/', 'content': 'Varanasi (India) weather in April 2025 ☀ Accurate weather forecast for Varanasi in ... 21 Apr. +38°+26°. 22 Apr. +39°+25°. ...
# ------
# StateSnapshot(values={'messages': [HumanMessage(content='What is the weather in Varanasi ?', additional_kwargs={}, response_metadata={}, id='9eeae9f1-1d7d-4104-9356-6147a2e448c0'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_9h7b', 'function': {'arguments': '{"query":"weather in Varanasi"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 81, 'prompt_tokens': 1021, 'total_tokens': 1102, 'completion_time': 0.0675, 'prompt_time': 0.141173133, 'queue_time': 0.23376384499999997, 'total_time': 0.208673133}, 'model_name': 'llama3-8b-8192', 'system_fingerprint': 'fp_a97cfe35ae', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-ee522ff3-7e73-4744-ba7e-904f649f981f-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Noida'}, 'id': 'call_9h7b', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1021, 'output_tokens': 81, 'total_tokens': 1102}), ToolMessage(content='[{\'title\': \'Weather in Noida\', \'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Noida\', \'region\': \'Uttar Pradesh\', \'country\': \'India\', \'lat\': 28.57, \'lon\': 77.32, \'tz_id\': \'Asia/Kolkata\', \'localtime_epoch\': 1745216597, \'localtime\': \'2025-04-21 11:53\'}, \'current\': {\'last_updated_epoch\': 1745216100, \'last_updated\': \'2025-04-21 11:45\', \'temp_c\': 36.3, \'temp_f\': 97.3, \'is_day\': 1, \'condition\': {\'text\': \'Mist\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/day/143.png\', \'code\': 1030}, \'wind_mph\': 6.5, \'wind_kph\': 10.4, \'wind_degree\': 215, \'wind_dir\': \'SW\', \'pressure_mb\': 1009.0, \'pressure_in\': 29.8, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 15, \'cloud\': 0, \'feelslike_c\': 34.8, \'feelslike_f\': 94.6, \'windchill_c\': 39.0, \'windchill_f\': 102.3, \'heatindex_c\': 38.5, \'heatindex_f\': 101.3, \'dewpoint_c\': -6.3, \'dewpoint_f\': 20.7, \'vis_km\': 4.5, \'vis_miles\': 2.0, \'uv\': 9.3, \'gust_mph\': 7.5, \'gust_kph\': 12.0}}", \'score\': 0.9688681}, {\'title\': \'Noida Weather Forecast 21 Apr 2025 - Times of India\', \'url\': \'https://timesofindia.indiatimes.com/weather/noida-weather-forecast-today/201301\', \'content\': "Today\'s Weather in Noida: In Noida today, the weather is expected to be Haze with a maximum temperature of 38°C and a minimum of 27°C. Sunrise in Noida is", \'score\': 0.9456058}]', name='tavily_search_results_json', id='7dbc12b2-ec4c-4a29-a7bb-b431a87cfad1', tool_call_id='call_9h7b'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_vmde', 'function': {'arguments': '{"query":"weather in Varanasi"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 78, 'prompt_tokens': 1626, 'total_tokens': 1704, 'completion_time': 0.065, 'prompt_time': 0.204505117, 'queue_time': 0.02333338900000001, 'total_time': 0.269505117}, 'model_name': 'llama3-8b-8192', 'system_fingerprint': 'fp_a97cfe35ae', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-5cf02b02-0173-466f-9938-aa7896b9037c-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Varanasi'}, 'id': 'call_vmde', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1626, 'output_tokens': 78, 'total_tokens': 1704})]}, next=('action',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f01e791-f57d-69a0-8004-c9de7469472a'}}, metadata={'source': 'loop', 'writes': {'llm': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_vmde', 'function': {'arguments': '{"query":"weather in Varanasi"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 78, 'prompt_tokens': 1626, 'total_tokens': 1704, 'completion_time': 0.065, 'prompt_time': 0.204505117, 'queue_time': 0.02333338900000001, 'total_time': 0.269505117}, 'model_name': 'llama ...
# ------
# StateSnapshot(values={'messages': [HumanMessage(content='What is the weather in Varanasi ?', additional_kwargs={}, response_metadata={}, id='9eeae9f1-1d7d-4104-9356-6147a2e448c0'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_9h7b', 'function': {'arguments': '{"query":"weather in Varanasi"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 81, 'prompt_tokens': 1021, 'total_tokens': 1102, 'completion_time': 0.0675, 'prompt_time': 0.141173133, 'queue_time': 0.23376384499999997, 'total_time': 0.208673133}, 'model_name': 'llama3-8b-8192', 'system_fingerprint': 'fp_a97cfe35ae', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-ee522ff3-7e73-4744-ba7e-904f649f981f-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Noida'}, 'id': 'call_9h7b', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1021, 'output_tokens': 81, 'total_tokens': 1102}), ToolMessage(content='[{\'title\': \'Weather in Noida\', \'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Noida\', \'region\': \'Uttar Pradesh\', \'country\': \'India\', \'lat\': 28.57, \'lon\': 77.32, \'tz_id\': \'Asia/Kolkata\', \'localtime_epoch\': 1745216597, \'localtime\': \'2025-04-21 11:53\'}, \'current\': {\'last_updated_epoch\': 1745216100, \'last_updated\': \'2025-04-21 11:45\', \'temp_c\': 36.3, \'temp_f\': 97.3, \'is_day\': 1, \'condition\': {\'text\': \'Mist\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/day/143.png\', \'code\': 1030}, \'wind_mph\': 6.5, \'wind_kph\': 10.4, \'wind_degree\': 215, \'wind_dir\': \'SW\', \'pressure_mb\': 1009.0, \'pressure_in\': 29.8, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 15, \'cloud\': 0, \'feelslike_c\': 34.8, \'feelslike_f\': 94.6, \'windchill_c\': 39.0, \'windchill_f\': 102.3, \'heatindex_c\': 38.5, \'heatindex_f\': 101.3, \'dewpoint_c\': -6.3, \'dewpoint_f\': 20.7, \'vis_km\': 4.5, \'vis_miles\': 2.0, \'uv\': 9.3, \'gust_mph\': 7.5, \'gust_kph\': 12.0}}", \'score\': 0.9688681}, {\'title\': \'Noida Weather Forecast 21 Apr 2025 - Times of India\', \'url\': \'https://timesofindia.indiatimes.com/weather/noida-weather-forecast-today/201301\', \'content\': "Today\'s Weather in Noida: In Noida today, the weather is expected to be Haze with a maximum temperature of 38°C and a minimum of 27°C. Sunrise in Noida is", \'score\': 0.9456058}]', name='tavily_search_results_json', id='7dbc12b2-ec4c-4a29-a7bb-b431a87cfad1', tool_call_id='call_9h7b')]}, next=('llm',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f01e791-eb27-6ac2-8003-a63a30c3d493'}}, metadata={'source': 'loop', 'writes': {'action': {'messages': [ToolMessage(content='[{\'title\': \'Weather in Noida\', \'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Noida\', \'region\': \'Uttar Pradesh\', \'country\': \'India\', \'lat\': 28.57, \'lon\': 77.32, \'tz_id\': \'Asia/Kolkata\', \'localtime_epoch\': 1745216597, \'localtime\': \'2025-04-21 11:53\'}, \'current\': {\'last_updated_epoch\': 1745216100, \'last_updated\': \'2025-04-21 11:45\', \'temp_c\': 36.3, \'temp_f\': 97.3, \'is_day\': 1, \'condition\': {\'text\': \'Mist\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/day/143.png\', \'code\': 1030}, \'wind_mph\': 6.5, \'wind_kph\': 10.4, \'wind_degree\': 215, \'wind_dir\': \'SW\', \'pressure_mb\': 1009.0, \'pressure_in\': 29.8, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 15, \'cloud\': 0, \'feelslike_c\': 34.8, \'feelslike_f\': 94.6, \'windchill_c\': 39.0, \'windchill_f\': 102.3, \'heatindex_c\': 38.5, \'heatindex_f\': 101.3, \'dewpoint_c\': -6.3, \'dewpoint_f\': 20.7, \'vis_km\': 4.5, \'vis_miles\': 2.0, \'uv\': 9.3, \'gust_mph\': 7.5, \'gust_kph\': 12.0}}", \'score\': 0.9688681}, {\'title\': \'Noida Weather Forecast 21 Apr 2025 - Times of India\', \'url\': \'https://timesofindia.indiatimes.com/weather/noida-weather-forecast-today/201 ...
# ------
# StateSnapshot(values={'messages': [HumanMessage(content='What is the weather in Varanasi ?', additional_kwargs={}, response_metadata={}, id='9eeae9f1-1d7d-4104-9356-6147a2e448c0'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_9h7b', 'function': {'arguments': '{"query":"weather in Varanasi"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 81, 'prompt_tokens': 1021, 'total_tokens': 1102, 'completion_time': 0.0675, 'prompt_time': 0.141173133, 'queue_time': 0.23376384499999997, 'total_time': 0.208673133}, 'model_name': 'llama3-8b-8192', 'system_fingerprint': 'fp_a97cfe35ae', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-ee522ff3-7e73-4744-ba7e-904f649f981f-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Noida'}, 'id': 'call_9h7b', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1021, 'output_tokens': 81, 'total_tokens': 1102})]}, next=('action',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f01e791-b6e2-68d2-8002-42ad104b5c73'}}, metadata={'source': 'update', 'writes': {'llm': {'messages': [HumanMessage(content='What is the weather in Varanasi ?', additional_kwargs={}, response_metadata={}, id='9eeae9f1-1d7d-4104-9356-6147a2e448c0'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_9h7b', 'function': {'arguments': '{"query":"weather in Varanasi"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 81, 'prompt_tokens': 1021, 'total_tokens': 1102, 'completion_time': 0.0675, 'prompt_time': 0.141173133, 'queue_time': 0.23376384499999997, 'total_time': 0.208673133}, 'model_name': 'llama3-8b-8192', 'system_fingerprint': 'fp_a97cfe35ae', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-ee522ff3-7e73-4744-ba7e-904f649f981f-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Noida'}, 'id': 'call_9h7b', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1021, 'output_tokens': 81, 'total_tokens': 1102})]}}, 'step': 2, 'parents': {}, 'thread_id': '2'}, created_at='2025-04-21T06:23:14.856571+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f01e791-b609-6b14-8001-5867b9d85469'}}, tasks=(PregelTask(id='f20f86f6-2490-410f-5e12-24b52b4a08d7', name='action', path=('__pregel_pull', 'action'), error=None, interrupts=(), state=None, result={'messages': [ToolMessage(content='[{\'title\': \'Weather in Noida\', \'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Noida\', \'region\': \'Uttar Pradesh\', \'country\': \'India\', \'lat\': 28.57, \'lon\': 77.32, \'tz_id\': \'Asia/Kolkata\', \'localtime_epoch\': 1745216597, \'localtime\': \'2025-04-21 11:53\'}, \'current\': {\'last_updated_epoch\': 1745216100, \'last_updated\': \'2025-04-21 11:45\', \'temp_c\': 36.3, \'temp_f\': 97.3, \'is_day\': 1, \'condition\': {\'text\': \'Mist\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/day/143.png\', \'code\': 1030}, \'wind_mph\': 6.5, \'wind_kph\': 10.4, \'wind_degree\': 215, \'wind_dir\': \'SW\', \'pressure_mb\': 1009.0, \'pressure_in\': 29.8, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 15, \'cloud\': 0, \'feelslike_c\': 34.8, \'feelslike_f\': 94.6, \'windchill_c\': 39.0, \'windchill_f\': 102.3, \'heatindex_c\': 38.5, \'heatindex_f\': 101.3, \'dewpoint_c\': -6.3, \'dewpoint_f\': 20.7, \'vis_km\': 4.5, \'vis_miles\': 2.0, \'uv\': 9.3, \'gust_mph\': 7.5, \'gust_kph\': 12.0}}", \'score\': 0.9688681}, {\'title\': \'Noida Weather Forecast 21 Apr 2025 - Times of India\', \'url\': \'https://timesofindia.indiatimes.com/weather/noida-weather-forecast-today/201301\', \'content\': "Today\'s Weather in Noida: In Noida today, the weather is expected to be Haze with a maximum temperature of 38°C and a minimum of 27°C. Sunrise in Noida is", \'score\': 0.9456058}]', name= ...
# ------
# StateSnapshot(values={'messages': [HumanMessage(content='What is the weather in Varanasi ?', additional_kwargs={}, response_metadata={}, id='9eeae9f1-1d7d-4104-9356-6147a2e448c0'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_9h7b', 'function': {'arguments': '{"query":"weather in Varanasi"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 81, 'prompt_tokens': 1021, 'total_tokens': 1102, 'completion_time': 0.0675, 'prompt_time': 0.141173133, 'queue_time': 0.23376384499999997, 'total_time': 0.208673133}, 'model_name': 'llama3-8b-8192', 'system_fingerprint': 'fp_a97cfe35ae', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-ee522ff3-7e73-4744-ba7e-904f649f981f-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Varanasi'}, 'id': 'call_9h7b', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1021, 'output_tokens': 81, 'total_tokens': 1102})]}, next=('action',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f01e791-b609-6b14-8001-5867b9d85469'}}, metadata={'source': 'loop', 'writes': {'llm': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_9h7b', 'function': {'arguments': '{"query":"weather in Varanasi"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 81, 'prompt_tokens': 1021, 'total_tokens': 1102, 'completion_time': 0.0675, 'prompt_time': 0.141173133, 'queue_time': 0.23376384499999997, 'total_time': 0.208673133}, 'model_name': 'llama3-8b-8192', 'system_fingerprint': 'fp_a97cfe35ae', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-ee522ff3-7e73-4744-ba7e-904f649f981f-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Varanasi'}, 'id': 'call_9h7b', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1021, 'output_tokens': 81, 'total_tokens': 1102})]}}, 'step': 1, 'parents': {}, 'thread_id': '2'}, created_at='2025-04-21T06:23:14.767746+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f01e791-af41-60ff-8000-386c80d3fc7b'}}, tasks=(PregelTask(id='2821705d-4a16-f2db-636a-b8d3907ef0bd', name='action', path=('__pregel_pull', 'action'), error=None, interrupts=(), state=None, result=None),))
# ------
# StateSnapshot(values={'messages': [HumanMessage(content='What is the weather in Varanasi ?', additional_kwargs={}, response_metadata={}, id='9eeae9f1-1d7d-4104-9356-6147a2e448c0')]}, next=('llm',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f01e791-af41-60ff-8000-386c80d3fc7b'}}, metadata={'source': 'loop', 'writes': None, 'step': 0, 'parents': {}, 'thread_id': '2'}, created_at='2025-04-21T06:23:14.056422+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f01e791-af3b-61c1-bfff-de0f0313c736'}}, tasks=(PregelTask(id='912c2e7d-35ad-d43c-404d-89d51d779fdf', name='llm', path=('__pregel_pull', 'llm'), error=None, interrupts=(), state=None, result={'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_9h7b', 'function': {'arguments': '{"query":"weather in Varanasi"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 81, 'prompt_tokens': 1021, 'total_tokens': 1102, 'completion_time': 0.0675, 'prompt_time': 0.141173133, 'queue_time': 0.23376384499999997, 'total_time': 0.208673133}, 'model_name': 'llama3-8b-8192', 'system_fingerprint': 'fp_a97cfe35ae', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-ee522ff3-7e73-4744-ba7e-904f649f981f-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Varanasi'}, 'id': 'call_9h7b', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1021, 'output_tokens': 81, 'total_tokens': 1102})]}),))
# ------
# StateSnapshot(values={'messages': []}, next=('__start__',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f01e791-af3b-61c1-bfff-de0f0313c736'}}, metadata={'source': 'input', 'writes': {'__start__': {'messages': [HumanMessage(content='What is the weather in Varanasi ?', additional_kwargs={}, response_metadata={})]}}, 'step': -1, 'parents': {}, 'thread_id': '2'}, created_at='2025-04-21T06:23:14.053984+00:00', parent_config=None, tasks=(PregelTask(id='f9994fc0-da9f-d68e-7b39-bcddb0c3f23c', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'messages': [HumanMessage(content='What is the weather in Varanasi ?', additional_kwargs={}, response_metadata={})]}),))
# ------

# %%
to_replay=states[-1]
to_replay
# Out:
# StateSnapshot(values={'messages': []}, next=('__start__',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f01e791-af3b-61c1-bfff-de0f0313c736'}}, metadata={'source': 'input', 'writes': {'__start__': {'messages': [HumanMessage(content='What is the weather in Varanasi ?', additional_kwargs={}, response_metadata={})]}}, 'step': -1, 'parents': {}, 'thread_id': '2'}, created_at='2025-04-21T06:23:14.053984+00:00', parent_config=None, tasks=(PregelTask(id='f9994fc0-da9f-d68e-7b39-bcddb0c3f23c', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'messages': [HumanMessage(content='What is the weather in Varanasi ?', additional_kwargs={}, response_metadata={})]}),))

# %%
x=to_replay.config
for event in abot.graph.stream(None,x):
    for k,v in event.items():
        print(v)
# Out:
# {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_zft9', 'function': {'arguments': '{"query":"weather in Varanasi"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 74, 'prompt_tokens': 2063, 'total_tokens': 2137, 'completion_time': 0.061666667, 'prompt_time': 0.25715902, 'queue_time': -0.34609064100000003, 'total_time': 0.318825687}, 'model_name': 'llama3-8b-8192', 'system_fingerprint': 'fp_179b0f92c9', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-a044b772-9097-44f3-a5f9-2d20f868243e-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Varanasi'}, 'id': 'call_zft9', 'type': 'tool_call'}], usage_metadata={'input_tokens': 2063, 'output_tokens': 74, 'total_tokens': 2137})]}
# ()

# %%
for event in abot.graph.stream(None,thread):
    for k,v in event.items():
        print(v)
# Out:
# Calling: {'name': 'tavily_search_results_json', 'args': {'query': 'weather in Varanasi'}, 'id': 'call_zft9', 'type': 'tool_call'}
# Back to the Model !!
# {'messages': [ToolMessage(content="[{'title': 'Weather in Varanasi in April 2025 (State of Uttar Pradesh)', 'url': 'https://world-weather.info/forecast/india/varanasi/april-2025/', 'content': 'Weather in Varanasi in April 2025. Varanasi Weather Forecast for April 2025 ... Monday, 21 April. +81°. Day. +100°. Clear sky. Tuesday, 22 April. +82°. Day. +99', 'score': 0.95407325}, {'title': 'Varanasi weather in April 2025 ⋆ Varanasi temperature in April ...', 'url': 'https://www.meteoprog.com/weather/Varanasi/month/april/', 'content': 'Varanasi (India) weather in April 2025 ☀ Accurate weather forecast for Varanasi in ... 21 Apr. +38°+26°. 22 Apr. +39°+25°. 23 Apr. +39°+26°. 24 Apr. +40°+25°. 25', 'score': 0.93161833}]", name='tavily_search_results_json', id='3da3793c-5462-4ec7-af38-3c7a00ed1209', tool_call_id='call_zft9')]}
# {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_vmkc', 'function': {'arguments': '{"query":"weather in Varanasi in April 2025"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 46, 'prompt_tokens': 1335, 'total_tokens': 1381, 'completion_time': 0.038333333, 'prompt_time': 0.166992743, 'queue_time': 0.016854079999999994, 'total_time': 0.205326076}, 'model_name': 'llama3-8b-8192', 'system_fingerprint': 'fp_a97cfe35ae', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-907379d3-8854-402b-b925-28c33383679d-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Varanasi in April 2025'}, 'id': 'call_vmkc', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1335, 'output_tokens': 46, 'total_tokens': 1381})]}
# ()

# %%
to_replay.values['messages'][-1].tool_calls[0]['args']['query']='weather in Varanasi, NDTV'
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 to_replay.values['messages'][-1].tool_calls[0]['args']['query']='weather in Varanasi, NDTV'
#
# IndexError: list index out of range
